# %% [markdown]
# # Study 1

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ### (c)

# %% [markdown]
# ### (d)

# %% [markdown]
# ### (e)

# %% [markdown]
# ### (f)

# %% [markdown]
# # Study 2

# %% [markdown]
# # Study 3
